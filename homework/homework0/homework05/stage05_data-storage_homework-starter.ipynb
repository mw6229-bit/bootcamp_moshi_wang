# %%
import os, pathlib, datetime as dt
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

RAW_DIR = pathlib.Path(os.getenv("DATA_DIR_RAW", "data/raw"))
PROC_DIR = pathlib.Path(os.getenv("DATA_DIR_PROCESSED", "data/processed"))

RAW_DIR.mkdir(parents=True, exist_ok=True)
PROC_DIR.mkdir(parents=True, exist_ok=True)

print("RAW_DIR:", RAW_DIR.resolve())
print("PROC_DIR:", PROC_DIR.resolve())
# Out:
# RAW_DIR: /Users/that_bat/bootcamp_moshi_wang/homework/homework0/homework05/data/raw
# PROC_DIR: /Users/that_bat/bootcamp_moshi_wang/homework/homework0/homework05/data/processed

# %%
df = pd.DataFrame({
    "date": pd.date_range("2026-08-01", periods=5),
    "ticker": ["NVDA", "AAPL", "MSFT", "AMZN", "META"],
    "price": [100.0, 110.0, 120.0, 130.0, 140.0]
})

df
# Out:
#         date ticker  price
# 0 2026-08-01   NVDA  100.0
# 1 2026-08-02   AAPL  110.0
# 2 2026-08-03   MSFT  120.0
# 3 2026-08-04   AMZN  130.0
# 4 2026-08-05   META  140.0

# %%
csv_path = RAW_DIR / "sample_data.csv"
parquet_path = PROC_DIR / "sample_data.parquet"

print(csv_path)
print(parquet_path)
# Out:
# data/raw/sample_data.csv
# data/processed/sample_data.parquet

# %%
df.to_csv(csv_path, index=False)
print("CSV saved:", csv_path)
# Out:
# CSV saved: data/raw/sample_data.csv

# %%
df.to_parquet(parquet_path, index=False)
print("Parquet saved:", parquet_path)
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_parquet(parquet_path, index=False)
#       2 print("Parquet saved:", parquet_path)
#
# File /opt/miniconda3-pbe/envs/fe-course/lib/python3.11/site-packages/pandas/core/frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
#    3137             path,
#    3138             engine,
#
# File /opt/miniconda3-pbe/envs/fe-course/lib/python3.11/site-packages/pandas/io/parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File /opt/miniconda3-pbe/envs/fe-course/lib/python3.11/site-packages/pandas/io/parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File /opt/miniconda3-pbe/envs/fe-course/lib/python3.11/site-packages/pandas/io/parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File /opt/miniconda3-pbe/envs/fe-course/lib/python3.11/site-packages/pandas/core/arrays/arrow/extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
# -> 2226 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:92, in pyarrow.lib.check_status()
# ---> 92 'Could not get source, probably due dynamically evaluated source code.'
#
# ArrowKeyError: A type extension with name pandas.period already defined
